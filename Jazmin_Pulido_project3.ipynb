# %% [markdown]
# # Project 3 -- Jazmin Pulido

# %% [markdown]
# **TA Help:** N/A
#
# - Helped with...
#
# **Collaboration:** N/A
#
# - Helped with...

# %% [markdown]
# ## Question 1

# %% [markdown]
# Using the 1990 airport data, find the average arrival delay for flights arriving to each airport.

# %%
import pandas as pd
myDF = pd.read_csv("/anvil/projects/tdm/data/flights/subset/1990.csv")
pd.set_option('display.max_rows', None)
myDF.groupby('Dest')['ArrDelay'].mean()
# Out:
# Dest
# ABE     4.774940
# ABQ     7.772013
# ACY     5.588076
# AGS     8.358385
# ALB     7.511260
# AMA     8.567987
# ANC    11.361536
# ATL     8.597035
# ATW   -11.253012
# AUS     6.218884
# AVL     5.561917
# AVP     7.239102
# AZO     3.334252
# BDL     7.501587
# BET    11.801754
# BFL     5.705599
# BGM     4.609019
# BGR    11.619406
# BHM     5.618216
# BIL     4.306908
# BIS     4.325692
# BLI     6.571663
# BNA     2.990541
# BOI     7.802144
# BOS     8.681390
# BTM     6.111433
# BTR     7.727585
# BTV     7.184737
# BUF     7.623859
# BUR     2.977912
# BWI     6.117801
# BZN     6.008305
# CAE     8.454399
# CAK     5.693481
# CCR     1.058360
# CDV     8.376488
# CHA     4.973240
# CHO     1.202899
# CHS     6.199248
# CID     7.011452
# CLE     6.613217
# CLT     4.672193
# CMH     6.809549
# CMI     4.130476
# COS     6.412706
# CPR     2.165428
# CRP     8.065865
# CRW     4.073368
# CSG     9.576809
# CVG     6.963399
# DAB     8.970992
# DAL     6.657802
# ...

# %% [markdown]
# Here I loaded in the 1990 airport data and used the groupby function to group the destinations. Then I showed the mean arrival delays using .mean().

# %% [markdown]
# ## Question 2

# %% [markdown]
# Find the sum of the amount spent (in the SPEND column) at each of the store regions (the STORE_R column).

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/8451/The_Complete_Journey_2_Master/5000_transactions.csv")
myDF.columns = ["BASKET_NUM", "HSHD_NUM", "PURCHASE", "PRODUCT_NUM", "SPEND", "UNITS", "STORE_R", "WEEK_NUM", "YEAR"]
myDF.groupby('STORE_R')['SPEND'].sum()
# Out:
# STORE_R
# CENTRAL     8897305.14
# EAST       11699446.86
# SOUTH       7957920.77
# WEST        9680106.54
# Name: SPEND, dtype: float64

# %% [markdown]
# Here I loaded the 5000_transactions.csv and assigned the column headers. I then and used the groupby function to group the store regions together. Then I showed the sum money spent using .sum().

# %% [markdown]
# ## Question 3

# %% [markdown]
# Find the total amount of money spent in 2016 altogether, and the total amount of money spent in 2017 altogether. (You can use the groupby to do this with just one cell.)

# %%
myDF.groupby('YEAR')['SPEND'].sum()
# Out:
# YEAR
# 2016    19051720.01
# 2017    19183059.30
# Name: SPEND, dtype: float64

# %% [markdown]
# For this problem, I used the groupby function to group the years together. Then I showed the sum money spent using .sum().

# %% [markdown]
# ## Question 4

# %% [markdown]
# Find the average height of the athletes in each country (the country is the NOC column).

# %%
myDF = pd.read_csv("/anvil/projects/tdm/data/olympics/athlete_events.csv")
myDF.groupby('NOC')['Height'].mean()
# Out:
# NOC
# AFG    170.592593
# AHO    177.294118
# ALB    173.000000
# ALG    174.702869
# AND    173.703704
# ANG    178.204082
# ANT    175.121739
# ANZ    176.730769
# ARG    176.604722
# ARM    171.937799
# ARU    173.219512
# ASA    175.666667
# AUS    176.874017
# AUT    177.369686
# AZE    172.717391
# BAH    177.440678
# BAN    166.187500
# BAR    176.598958
# BDI    172.631579
# BEL    176.143175
# BEN    173.683333
# BER    177.405797
# BHU    166.517241
# BIH    178.633929
# BIZ    175.054795
# BLR    174.256440
# BOH    174.000000
# BOL    171.295652
# BOT    175.809524
# BRA    177.637147
# BRN    173.424528
# BRU    166.111111
# BUL    172.830911
# BUR    176.000000
# CAF    179.276596
# CAM    166.719298
# CAN    174.978716
# CAY    179.506849
# CGO    174.585366
# CHA    176.558824
# CHI    174.986989
# CHN    172.602743
# CIV    176.415094
# CMR    173.634615
# COD    175.358209
# COK    171.324324
# COL    169.915220
# COM    170.866667
# CPV    175.888889
# ...

# %% [markdown]
# I first loaded in the athlete_events dataset. I then used the groupby function to group the countries (NOC) together. Then I showed the average height using .mean().

# %% [markdown]
# ## Question 5

# %% [markdown]
# Find the average height of the athletes in each sport

# %%
myDF.groupby('Sport')['Height'].mean()
# Out:
# Sport
# Aeronautics                         NaN
# Alpine Skiing                173.489052
# Alpinism                            NaN
# Archery                      173.203085
# Art Competitions             174.644068
# Athletics                    176.256268
# Badminton                    174.178803
# Baseball                     182.599291
# Basketball                   190.869879
# Basque Pelota                       NaN
# Beach Volleyball             186.144954
# Biathlon                     174.034766
# Bobsleigh                    181.437500
# Boxing                       172.825688
# Canoeing                     178.539568
# Cricket                             NaN
# Croquet                             NaN
# Cross Country Skiing         173.249185
# Curling                      174.203125
# Cycling                      176.108826
# Diving                       166.634264
# Equestrianism                174.375272
# Fencing                      177.164177
# ...

# %% [markdown]
# Similarly to the previous problem, I used the groupby function to group the sport names together. Then I showed the average height using .mean().

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
